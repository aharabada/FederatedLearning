# %%
import os
import numpy as np
import pickle

from DataCollector import CollectedData

# since this Notebook is in the code folder, we need to go up one level, so every module works as expected
if(os.getcwd().endswith("code")):
    os.chdir("..")
print(os.getcwd())
# Out:
# c:\Users\PC\Desktop\FederatedLearning\FederatedLearning

# %%
for root, dirnames, filenames in os.walk("results"):
    for file in filenames:
        if file.endswith(".pkl"):
            print(f"Loading {file}")
            data = pickle.load(open(f"{root}/{file}", "rb"))
            for key, value in data.plot_data.items():
                mean = np.mean(value, axis=0)
                std = np.std(value, axis=0)
                print("=" * 50)
                print(f"{file.removesuffix('_collected_data.pkl')} - {key}")
                print("=" * 50)
                for i in range(len(mean)):
                    print(f"Step {i}: {mean[i]:.4f} \\\\ $\pm$ {std[i]:.4f}")
# Out:
# Loading FedAvg_GT_N10_R10_C5_I1_D20_collected_data.pkl
# ==================================================
# FedAvg_GT_N10_R10_C5_I1_D20 - Loss
# ==================================================
# Step 0: 0.1742 \\ $\pm$ 0.0000
# Step 1: 0.1532 \\ $\pm$ 0.0022
# Step 2: 0.1598 \\ $\pm$ 0.0044
# Step 3: 0.1628 \\ $\pm$ 0.0049
# Step 4: 0.1592 \\ $\pm$ 0.0050
# Step 5: 0.1584 \\ $\pm$ 0.0049
# Step 6: 0.1610 \\ $\pm$ 0.0059
# Step 7: 0.1673 \\ $\pm$ 0.0117
# Step 8: 0.1565 \\ $\pm$ 0.0075
# Step 9: 0.1491 \\ $\pm$ 0.0049
# Step 10: 0.1568 \\ $\pm$ 0.0103
# ==================================================
# FedAvg_GT_N10_R10_C5_I1_D20 - IoU
# ==================================================
# Step 0: 0.6599 \\ $\pm$ 0.0000
# Step 1: 0.7211 \\ $\pm$ 0.0072
# Step 2: 0.7035 \\ $\pm$ 0.0112
# Step 3: 0.6892 \\ $\pm$ 0.0124
# Step 4: 0.6950 \\ $\pm$ 0.0129
# Step 5: 0.6960 \\ $\pm$ 0.0120
# Step 6: 0.6886 \\ $\pm$ 0.0119
# Step 7: 0.6807 \\ $\pm$ 0.0185
# Step 8: 0.6886 \\ $\pm$ 0.0148
# Step 9: 0.6977 \\ $\pm$ 0.0080
# Step 10: 0.6869 \\ $\pm$ 0.0150
# Loading FedAvg_MCD_N10_R10_C5_I1_D20_collected_data.pkl
# ==================================================
# FedAvg_MCD_N10_R10_C5_I1_D20 - Loss
# ==================================================
# Step 0: 0.1742 \\ $\pm$ 0.0000
# Step 1: 0.1817 \\ $\pm$ 0.0271
# Step 2: 0.1892 \\ $\pm$ 0.0104
# Step 3: 0.2108 \\ $\pm$ 0.0251
# Step 4: 0.2499 \\ $\pm$ 0.0345
# Step 5: 0.2714 \\ $\pm$ 0.0335
# Step 6: 0.2964 \\ $\pm$ 0.0492
# Step 7: 0.3502 \\ $\pm$ 0.0997
# Step 8: 0.3668 \\ $\pm$ 0.1073
# Step 9: 0.3970 \\ $\pm$ 0.1118
# Step 10: 0.4157 \\ $\pm$ 0.0992
# ==================================================
# FedAvg_MCD_N10_R10_C5_I1_D20 - IoU
# ==================================================
# Step 0: 0.6599 \\ $\pm$ 0.0000
# Step 1: 0.6787 \\ $\pm$ 0.0378
# Step 2: 0.6653 \\ $\pm$ 0.0251
# Step 3: 0.6178 \\ $\pm$ 0.0542
# Step 4: 0.5353 \\ $\pm$ 0.0707
# Step 5: 0.4979 \\ $\pm$ 0.0671
# Step 6: 0.4558 \\ $\pm$ 0.0962
# Step 7: 0.3552 \\ $\pm$ 0.1803
# Step 8: 0.3299 \\ $\pm$ 0.1853
# Step 9: 0.2766 \\ $\pm$ 0.1881
# Step 10: 0.2435 \\ $\pm$ 0.1691
# Loading FedAvg_MCD_N10_R20_C5_I1_D5_collected_data.pkl
# ==================================================
# FedAvg_MCD_N10_R20_C5_I1_D5 - Loss
# ==================================================
# Step 0: 0.1742 \\ $\pm$ 0.0000
# Step 1: 0.1908 \\ $\pm$ 0.0208
# Step 2: 0.1692 \\ $\pm$ 0.0094
# Step 3: 0.2231 \\ $\pm$ 0.0328
# Step 4: 0.2085 \\ $\pm$ 0.0319
# Step 5: 0.1858 \\ $\pm$ 0.0177
# Step 6: 0.1867 \\ $\pm$ 0.0137
# Step 7: 0.1838 \\ $\pm$ 0.0073
# Step 8: 0.1878 \\ $\pm$ 0.0102
# Step 9: 0.1941 \\ $\pm$ 0.0074
# Step 10: 0.2038 \\ $\pm$ 0.0129
# Step 11: 0.2044 \\ $\pm$ 0.0101
# Step 12: 0.2115 \\ $\pm$ 0.0085
# Step 13: 0.2137 \\ $\pm$ 0.0059
# Step 14: 0.2216 \\ $\pm$ 0.0084
# Step 15: 0.2215 \\ $\pm$ 0.0057
# Step 16: 0.2257 \\ $\pm$ 0.0088
# Step 17: 0.2276 \\ $\pm$ 0.0115
# Step 18: 0.2322 \\ $\pm$ 0.0121
# Step 19: 0.2574 \\ $\pm$ 0.0194
# Step 20: 0.2407 \\ $\pm$ 0.0087
# ==================================================
# FedAvg_MCD_N10_R20_C5_I1_D5 - IoU
# ==================================================
# Step 0: 0.6599 \\ $\pm$ 0.0000
# Step 1: 0.6267 \\ $\pm$ 0.0379
# Step 2: 0.6808 \\ $\pm$ 0.0175
# Step 3: 0.6014 \\ $\pm$ 0.0472
# Step 4: 0.6320 \\ $\pm$ 0.0352
# Step 5: 0.6645 \\ $\pm$ 0.0292
# Step 6: 0.6529 \\ $\pm$ 0.0306
# Step 7: 0.6665 \\ $\pm$ 0.0214
# Step 8: 0.6676 \\ $\pm$ 0.0252
# Step 9: 0.6450 \\ $\pm$ 0.0171
# Step 10: 0.6286 \\ $\pm$ 0.0271
# Step 11: 0.6288 \\ $\pm$ 0.0215
# Step 12: 0.6157 \\ $\pm$ 0.0188
# Step 13: 0.6110 \\ $\pm$ 0.0122
# Step 14: 0.5916 \\ $\pm$ 0.0184
# Step 15: 0.5949 \\ $\pm$ 0.0109
# Step 16: 0.5889 \\ $\pm$ 0.0154
# Step 17: 0.5828 \\ $\pm$ 0.0258
# Step 18: 0.5794 \\ $\pm$ 0.0271
# Step 19: 0.5241 \\ $\pm$ 0.0418
# Step 20: 0.5620 \\ $\pm$ 0.0208
# Loading FedAvg_MCD_N10_R5_C5_I1_D50_collected_data.pkl
# ==================================================
# FedAvg_MCD_N10_R5_C5_I1_D50 - Loss
# ==================================================
# Step 0: 0.1742 \\ $\pm$ 0.0000
# Step 1: 0.2065 \\ $\pm$ 0.0131
# Step 2: 0.2697 \\ $\pm$ 0.0264
# Step 3: 0.3541 \\ $\pm$ 0.0886
# Step 4: 0.4520 \\ $\pm$ 0.0926
# Step 5: 0.5163 \\ $\pm$ 0.0564
# ==================================================
# FedAvg_MCD_N10_R5_C5_I1_D50 - IoU
# ==================================================
# Step 0: 0.6599 \\ $\pm$ 0.0000
# Step 1: 0.6259 \\ $\pm$ 0.0298
# Step 2: 0.4884 \\ $\pm$ 0.0554
# Step 3: 0.3412 \\ $\pm$ 0.1632
# Step 4: 0.1682 \\ $\pm$ 0.1557
# Step 5: 0.0603 \\ $\pm$ 0.0913
